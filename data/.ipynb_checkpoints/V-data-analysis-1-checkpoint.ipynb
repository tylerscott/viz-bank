# %%
import pandas as pd
import numpy as np


import matplotlib.pyplot as plt
from scipy.stats import binned_statistic
import seaborn as sns

# %%
orig_df = pd.read_csv("bank-full.csv", sep=";")

# %%
orig_df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
orig_df.isna().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
df = orig_df.copy()

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
df.job.unique()
# Out:
# array(['management', 'technician', 'entrepreneur', 'blue-collar',
#        'unknown', 'retired', 'admin.', 'services', 'self-employed',
#        'unemployed', 'housemaid', 'student'], dtype=object)

# %%
df.job.value_counts().plot(kind='bar')

# %%
df.groupby('y').job.value_counts().unstack(0).plot.barh()

# %%
unemp_df = df[df['job']=="unemployed"]
unemp_df.head()
# Out:
#      age         job  marital  education default  balance housing loan  \
# 134   28  unemployed   single   tertiary      no        0     yes   no
# 142   57  unemployed  married   tertiary      no       42      no   no
# 147   48  unemployed  married  secondary      no      293     yes   no
# 176   48  unemployed  married  secondary      no       41     yes   no
# 217   53  unemployed  married    unknown      no       13      no   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome   y
# 134  unknown    5   may       125         2     -1         0  unknown  no
# 142  unknown    5   may        46         1     -1         0  unknown  no
# 147  unknown    5   may       243         1     -1         0  unknown  no
# 176  unknown    5   may       179         2     -1         0  unknown  no
# 217  unknown    5   may       410         3     -1         0  unknown  no

# %%
unemp_df.groupby('y').housing.value_counts().unstack(0).plot.barh()

# %%
unemp_df.groupby('y').marital.value_counts().unstack(0).plot.barh()

# %%
df["balance"].max()
# Out:
# 102127

# %%
unemp_df.balance.max()
# Out:
# 44134

# %%
# %time
cond_plot = sns.FacetGrid(data=df[1:15000], col='job', hue='y', col_wrap=4)
cond_plot.map(sns.scatterplot , 'balance', 'age');
# Out:
# Wall time: 0 ns

# %%
cond_plot.map?
